# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
from rmask import RoadCropProc

# %%
def make_faux_model():
    return lambda img: imageio.imread("results/actual_binary.png")

# %%
imageio.imread("results/actual_binary.png").shape
# Out:
# (358, 731, 4)

# %%
q = RoadCropProc(make_faux_model)

# %%
a, _ = q(np.random.rand(358, 731, 4), None)

# %%
plt.imshow(a)

# %%
q = highest_pixels(image)

# %%
p = np.zeros(image.shape)
p[:130, :] = [1] * 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-11b3df4dfdd9> in <module>
#       1 p = np.zeros(image.shape)
# ----> 2 p[:130, :] = [1] * 100
#
# ValueError: could not broadcast input array from shape (100) into shape (130,731,4)

# %%
plt.imshow(p)

# %%
def load_lanet():
    pass

# %%
y = cut_to_uppermost(b, w)

# %%
plt.imshow(y)

# %%
p = np.zeros(image.shape)
for i in range(len(q)):
    p[:q[i], i, :] = 1

# %%
plt.imshow(p)

# %%
w = interpolate_gaps(q)

# %%
m = create_mask(w, p.shape[0])

# %%
plt.imshow(m)

# %%
z = np.random.rand(*p.shape)

# %%
plt.imshow(z)

# %%
b = z * m[:, :, None]
plt.imshow(b)
